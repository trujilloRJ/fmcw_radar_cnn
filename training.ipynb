# %%
# %load_ext autoreload
# %autoreload 2

import itertools
import os
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from nn_utils import (
    MapsDataset,
    Conv2Net,
    Conv1Net,
    MLPNet,
    ConvSimpleNet,
    train_validate,
    plot_train_val_loss,
    train_model,
    set_seed,
)

# %%
DIR = os.path.abspath("./dataset")
LABEL_MAPPER = {"Cars": 0, "Drones": 1, "People": 2}
INV_LABEL_MAPPER = {v: k for k, v in LABEL_MAPPER.items()}
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
SEED = 0

# def get_data_for_label(label):
#     X, y = [], []
#     for root, dirs, files in os.walk(os.path.join(DIR, label)):
#         for file in files:
#             if file.endswith('.csv'):
#                 y.append(LABEL_MAPPER[label])
#                 df = pd.read_csv(os.path.join(root, file), sep=',', header=None)
#                 X.append(df.values)
#     print(f'Loaded {len(y)} examples for label {label} encoded with {LABEL_MAPPER[label]}')
#     return X, y

# X_cars, y_cars = get_data_for_label('Cars')
# X_drones, y_drones = get_data_for_label('Drones')
# X_people, y_people = get_data_for_label('People')

# X = X_cars + X_drones + X_people
# y = y_cars + y_drones + y_people
# X, y = np.array(X), np.array(y)

# %store X
# %store y

# %store -r X
# %store -r y

# %%
# Data normalization to normal distribution
def standard_normalizer(X):
    n_samples = X.shape[0]
    for sid in range(n_samples):
        matrix = X[sid, :, :]
        X[sid, :, :] = (matrix - np.mean(matrix)) / np.std(matrix)
    return X


X = standard_normalizer(X)
n_total = len(X)

# separating train, validation, test
test_size = 0.1
val_size = 0.2
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y, test_size=test_size, random_state=SEED, stratify=y
)
X_train, X_val, y_train, y_val = train_test_split(
    X_trainval,
    y_trainval,
    test_size=val_size / (1 - test_size),
    random_state=SEED,
    stratify=y_trainval,
)
train_dataset = MapsDataset(X_train, y_train)
val_dataset = MapsDataset(X_val, y_val)

print(f"Training: {len(X_train)} samples -> {len(X_train)/n_total*100:.2f} %")
print(f"Validation: {len(X_val)} samples -> {len(X_val)/n_total*100:.2f} %")
print(f"Test: {len(X_test)} samples -> {len(X_test)/n_total*100:.2f} %")
# Out:
# Training: 12239 samples -> 70.00 %
# Validation: 3497 samples -> 20.00 %
# Test: 1749 samples -> 10.00 %

# %%
# check that it overfit a small batch
# batch_size = 2
# num_epochs = 100
# lr = 1e-4
# train_dataset = MapsDataset(X_train[:batch_size], y_train[:batch_size])
# val_dataset = MapsDataset(X_val[:batch_size], y_val[:batch_size])
# train_loss, val_loss, train_acc, val_acc = train_model(train_dataset, val_dataset, batch_size, num_epochs, lr)

# %%
set_seed(SEED+3)
batch_size = 32
lr = 2e-4
num_epochs = 25
k1_size = (3, 3)
p_dropout = 0.
model = Conv1Net(k1_size)
train_loss, val_loss, train_acc, val_acc, model = train_model(
    model, train_dataset, val_dataset, batch_size, num_epochs, lr
)
fig = plot_train_val_loss(
    num_epochs,
    train_loss,
    train_acc,
    val_loss,
    val_acc,
    title=f"{type(model).__name__} | lr={lr} | bs={batch_size}",
)
plt.tight_layout()
fig.savefig('./figures/conv1_results.png')
# Out:
# --- Epoch 1/25:
# Train      -> loss = 0.433 | acc = 0.857
# Validation -> loss = 0.237 | acc = 0.919
# --- Epoch 2/25:
# Train      -> loss = 0.218 | acc = 0.917
# Validation -> loss = 0.225 | acc = 0.924
# --- Epoch 3/25:
# Train      -> loss = 0.192 | acc = 0.927
# Validation -> loss = 0.205 | acc = 0.931
# --- Epoch 4/25:
# Train      -> loss = 0.172 | acc = 0.934
# Validation -> loss = 0.209 | acc = 0.922
# --- Epoch 5/25:
# Train      -> loss = 0.161 | acc = 0.938
# Validation -> loss = 0.215 | acc = 0.920
# --- Epoch 6/25:
# Train      -> loss = 0.153 | acc = 0.943
# Validation -> loss = 0.202 | acc = 0.925
# --- Epoch 7/25:
# Train      -> loss = 0.143 | acc = 0.947
# Validation -> loss = 0.199 | acc = 0.930
# --- Epoch 8/25:
# Train      -> loss = 0.137 | acc = 0.950
# Validation -> loss = 0.199 | acc = 0.929
# --- Epoch 9/25:
# Train      -> loss = 0.128 | acc = 0.955
# Validation -> loss = 0.201 | acc = 0.932
# --- Epoch 10/25:
# Train      -> loss = 0.120 | acc = 0.954
# Validation -> loss = 0.198 | acc = 0.930
# --- Epoch 11/25:
# Train      -> loss = 0.111 | acc = 0.960
# Validation -> loss = 0.223 | acc = 0.918
# --- Epoch 12/25:
# Train      -> loss = 0.103 | acc = 0.962
# Validation -> loss = 0.212 | acc = 0.927
# --- Epoch 13/25:
# Train      -> loss = 0.090 | acc = 0.967
# Validation -> loss = 0.337 | acc = 0.880
# --- Epoch 14/25:
# Train      -> loss = 0.092 | acc = 0.967
# Validation -> loss = 0.215 | acc = 0.929
# --- Epoch 15/25:
# Train      -> loss = 0.077 | acc = 0.973
# Validation -> loss = 0.251 | acc = 0.923
# --- Epoch 16/25:
# Train      -> loss = 0.076 | acc = 0.973
# Validation -> loss = 0.235 | acc = 0.923
# --- Epoch 17/25:
# Train      -> loss = 0.061 | acc = 0.979
# Validation -> loss = 0.237 | acc = 0.929
# --- Epoch 18/25:
# Train      -> loss = 0.055 | acc = 0.980
# Validation -> loss = 0.263 | acc = 0.927
# --- Epoch 19/25:
# Train      -> loss = 0.049 | acc = 0.984
# Validation -> loss = 0.274 | acc = 0.926
# --- Epoch 20/25:
# Train      -> loss = 0.041 | acc = 0.986
# Validation -> loss = 0.274 | acc = 0.920
# --- Epoch 21/25:
# Train      -> loss = 0.032 | acc = 0.991
# Validation -> loss = 0.295 | acc = 0.925
# --- Epoch 22/25:
# Train      -> loss = 0.031 | acc = 0.990
# Validation -> loss = 0.297 | acc = 0.923
# --- Epoch 23/25:
# Train      -> loss = 0.026 | acc = 0.992
# Validation -> loss = 0.317 | acc = 0.923
# --- Epoch 24/25:
# Train      -> loss = 0.023 | acc = 0.993
# Validation -> loss = 0.324 | acc = 0.927
# --- Epoch 25/25:
# Train      -> loss = 0.016 | acc = 0.995
# Validation -> loss = 0.352 | acc = 0.921
# c:\javier\personal_projects\ml\radar-doppler\nn_utils.py:241: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(np.arange(num_epochs), val_loss, "r-", color='royalblue', label="validation loss")
# c:\javier\personal_projects\ml\radar-doppler\nn_utils.py:242: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(np.arange(num_epochs), val_acc, "r--", color='royalblue', label="validation acc")

# %%
from torchsummary import summary

summary(model, input_size=(1, 11, 61))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 20, 9, 59]             200
#               ReLU-2            [-1, 20, 9, 59]               0
#          MaxPool2d-3            [-1, 20, 4, 29]               0
#             Linear-4                   [-1, 64]         148,544
#               ReLU-5                   [-1, 64]               0
#             Linear-6                   [-1, 64]           4,160
#               ReLU-7                   [-1, 64]               0
#            Dropout-8                   [-1, 64]               0
#             Linear-9                   [-1, 64]           4,160
#              ReLU-10                   [-1, 64]               0
#           Dropout-11                   [-1, 64]               0
#            Linear-12                    [-1, 3]             195
#              ReLU-13                    [-1, 3]               0
#           Dropout-14                    [-1, 3]               0
# ================================================================
# Total params: 157,259
# Trainable params: 157,259
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.18
# Params size (MB): 0.60
# Estimated Total Size (MB): 0.79
# ----------------------------------------------------------------

# %%
set_seed(SEED)
batch_size = 32
lr = 2e-4
num_epochs = 25
k1_size = (3, 3)
k2_size = (3, 3)
model = Conv2Net(k1_size, k2_size)
train_loss, val_loss, train_acc, val_acc, model = train_model(
    model, train_dataset, val_dataset, batch_size, num_epochs, lr
)
fig = plot_train_val_loss(
    num_epochs,
    train_loss,
    train_acc,
    val_loss,
    val_acc,
    title=f"{type(model).__name__} | lr={lr} | bs={batch_size}",
)
plt.tight_layout()
fig.savefig('./figures/conv_results.png')
# Out:
# --- Epoch 1/25:
# Train      -> loss = 0.546 | acc = 0.801
# Validation -> loss = 0.290 | acc = 0.899
# --- Epoch 2/25:
# Train      -> loss = 0.253 | acc = 0.903
# Validation -> loss = 0.233 | acc = 0.918
# --- Epoch 3/25:
# Train      -> loss = 0.218 | acc = 0.916
# Validation -> loss = 0.240 | acc = 0.914
# --- Epoch 4/25:
# Train      -> loss = 0.203 | acc = 0.922
# Validation -> loss = 0.201 | acc = 0.926
# --- Epoch 5/25:
# Train      -> loss = 0.192 | acc = 0.927
# Validation -> loss = 0.197 | acc = 0.930
# --- Epoch 6/25:
# Train      -> loss = 0.182 | acc = 0.929
# Validation -> loss = 0.198 | acc = 0.923
# --- Epoch 7/25:
# Train      -> loss = 0.174 | acc = 0.935
# Validation -> loss = 0.191 | acc = 0.932
# --- Epoch 8/25:
# Train      -> loss = 0.164 | acc = 0.937
# Validation -> loss = 0.208 | acc = 0.926
# --- Epoch 9/25:
# Train      -> loss = 0.159 | acc = 0.938
# Validation -> loss = 0.178 | acc = 0.935
# --- Epoch 10/25:
# Train      -> loss = 0.153 | acc = 0.943
# Validation -> loss = 0.171 | acc = 0.937
# --- Epoch 11/25:
# Train      -> loss = 0.150 | acc = 0.943
# Validation -> loss = 0.169 | acc = 0.935
# --- Epoch 12/25:
# Train      -> loss = 0.142 | acc = 0.947
# Validation -> loss = 0.194 | acc = 0.933
# --- Epoch 13/25:
# Train      -> loss = 0.139 | acc = 0.948
# Validation -> loss = 0.165 | acc = 0.939
# --- Epoch 14/25:
# Train      -> loss = 0.136 | acc = 0.949
# Validation -> loss = 0.164 | acc = 0.939
# --- Epoch 15/25:
# Train      -> loss = 0.129 | acc = 0.951
# Validation -> loss = 0.159 | acc = 0.942
# --- Epoch 16/25:
# Train      -> loss = 0.125 | acc = 0.954
# Validation -> loss = 0.169 | acc = 0.937
# --- Epoch 17/25:
# Train      -> loss = 0.124 | acc = 0.955
# Validation -> loss = 0.183 | acc = 0.930
# --- Epoch 18/25:
# Train      -> loss = 0.119 | acc = 0.957
# Validation -> loss = 0.164 | acc = 0.941
# --- Epoch 19/25:
# Train      -> loss = 0.115 | acc = 0.957
# Validation -> loss = 0.183 | acc = 0.932
# --- Epoch 20/25:
# Train      -> loss = 0.113 | acc = 0.958
# Validation -> loss = 0.159 | acc = 0.940
# --- Epoch 21/25:
# Train      -> loss = 0.109 | acc = 0.961
# Validation -> loss = 0.160 | acc = 0.941
# --- Epoch 22/25:
# Train      -> loss = 0.105 | acc = 0.963
# Validation -> loss = 0.163 | acc = 0.939
# --- Epoch 23/25:
# Train      -> loss = 0.104 | acc = 0.962
# Validation -> loss = 0.155 | acc = 0.943
# --- Epoch 24/25:
# Train      -> loss = 0.099 | acc = 0.964
# Validation -> loss = 0.157 | acc = 0.939
# --- Epoch 25/25:
# Train      -> loss = 0.097 | acc = 0.965
# Validation -> loss = 0.159 | acc = 0.941

# %%
summary(model, input_size=(1, 11, 61))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 10, 9, 59]             100
#               ReLU-2            [-1, 10, 9, 59]               0
#          MaxPool2d-3            [-1, 10, 4, 29]               0
#             Conv2d-4            [-1, 20, 2, 27]           1,820
#               ReLU-5            [-1, 20, 2, 27]               0
#          MaxPool2d-6            [-1, 20, 1, 13]               0
#             Linear-7                   [-1, 64]          16,704
#               ReLU-8                   [-1, 64]               0
#             Linear-9                   [-1, 64]           4,160
#              ReLU-10                   [-1, 64]               0
#            Linear-11                    [-1, 3]             195
# ================================================================
# Total params: 22,979
# Trainable params: 22,979
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.20
# ----------------------------------------------------------------

# %%
# Check performance on test set

test_dataset = MapsDataset(X_test, y_test)
model.eval()
Xtr, ytr = torch.from_numpy(X_test).float().to(DEVICE), torch.from_numpy(y_test).type(torch.LongTensor).to(DEVICE)
y_pred = model(Xtr[None, :].permute(1, 0, 2, 3))
pred_labels = torch.argmax(y_pred, dim=1)
(torch.sum(pred_labels == ytr)).item()/len(ytr)

# %% [markdown]
# ### Additional explorations

# %%
# try with learning rate decay
set_seed(SEED)
num_epochs = 100
model = Conv2Net(k1_size, k2_size)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
lr_decay = lambda epoch: 0.99**epoch
lr_scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lr_decay)
train_loss, val_loss, train_acc, val_acc, model = train_model(
    model,
    train_dataset,
    val_dataset,
    batch_size,
    num_epochs,
    lr,
    optimizer=optimizer,
    scheduler=lr_scheduler,
)
fig = plot_train_val_loss(
    num_epochs,
    train_loss,
    train_acc,
    val_loss,
    val_acc,
    title=f"lr={lr} | bs={batch_size}",
)
# Out:
# --- Epoch 1/100:
# Train      -> loss = 0.771 | acc = 0.634
# Validation -> loss = 0.460 | acc = 0.839
# --- Epoch 2/100:
# Train      -> loss = 0.354 | acc = 0.872
# Validation -> loss = 0.296 | acc = 0.897
# --- Epoch 3/100:
# Train      -> loss = 0.265 | acc = 0.905
# Validation -> loss = 0.250 | acc = 0.911
# --- Epoch 4/100:
# Train      -> loss = 0.231 | acc = 0.914
# Validation -> loss = 0.228 | acc = 0.922
# --- Epoch 5/100:
# Train      -> loss = 0.214 | acc = 0.921
# Validation -> loss = 0.226 | acc = 0.921
# --- Epoch 6/100:
# Train      -> loss = 0.209 | acc = 0.920
# Validation -> loss = 0.215 | acc = 0.926
# --- Epoch 7/100:
# Train      -> loss = 0.200 | acc = 0.922
# Validation -> loss = 0.204 | acc = 0.930
# --- Epoch 8/100:
# Train      -> loss = 0.190 | acc = 0.927
# Validation -> loss = 0.201 | acc = 0.931
# --- Epoch 9/100:
# Train      -> loss = 0.187 | acc = 0.930
# Validation -> loss = 0.198 | acc = 0.930
# --- Epoch 10/100:
# Train      -> loss = 0.181 | acc = 0.931
# Validation -> loss = 0.192 | acc = 0.931
# --- Epoch 11/100:
# Train      -> loss = 0.176 | acc = 0.934
# Validation -> loss = 0.192 | acc = 0.933
# --- Epoch 12/100:
# Train      -> loss = 0.172 | acc = 0.935
# Validation -> loss = 0.189 | acc = 0.933
# --- Epoch 13/100:
# Train      -> loss = 0.169 | acc = 0.935
# Validation -> loss = 0.190 | acc = 0.930
# --- Epoch 14/100:
# Train      -> loss = 0.164 | acc = 0.939
# Validation -> loss = 0.185 | acc = 0.937
# --- Epoch 15/100:
# Train      -> loss = 0.160 | acc = 0.939
# Validation -> loss = 0.193 | acc = 0.926
# --- Epoch 16/100:
# Train      -> loss = 0.157 | acc = 0.941
# Validation -> loss = 0.178 | acc = 0.935
# --- Epoch 17/100:
# Train      -> loss = 0.154 | acc = 0.943
# Validation -> loss = 0.175 | acc = 0.939
# --- Epoch 18/100:
# Train      -> loss = 0.152 | acc = 0.942
# Validation -> loss = 0.173 | acc = 0.937
# --- Epoch 19/100:
# Train      -> loss = 0.147 | acc = 0.945
# Validation -> loss = 0.173 | acc = 0.937
# --- Epoch 20/100:
# Train      -> loss = 0.145 | acc = 0.947
# Validation -> loss = 0.172 | acc = 0.938
# --- Epoch 21/100:
# Train      -> loss = 0.141 | acc = 0.949
# Validation -> loss = 0.173 | acc = 0.936
# --- Epoch 22/100:
# Train      -> loss = 0.140 | acc = 0.948
# Validation -> loss = 0.170 | acc = 0.940
# --- Epoch 23/100:
# Train      -> loss = 0.138 | acc = 0.949
# Validation -> loss = 0.174 | acc = 0.937
# --- Epoch 24/100:
# Train      -> loss = 0.136 | acc = 0.951
# Validation -> loss = 0.174 | acc = 0.936
# --- Epoch 25/100:
# Train      -> loss = 0.133 | acc = 0.950
# Validation -> loss = 0.171 | acc = 0.940
# --- Epoch 26/100:
# Train      -> loss = 0.130 | acc = 0.951
# Validation -> loss = 0.163 | acc = 0.941
# --- Epoch 27/100:
# Train      -> loss = 0.127 | acc = 0.954
# Validation -> loss = 0.174 | acc = 0.935
# --- Epoch 28/100:
# Train      -> loss = 0.127 | acc = 0.952
# Validation -> loss = 0.164 | acc = 0.939
# --- Epoch 29/100:
# Train      -> loss = 0.123 | acc = 0.955
# Validation -> loss = 0.165 | acc = 0.938
# --- Epoch 30/100:
# Train      -> loss = 0.121 | acc = 0.957
# Validation -> loss = 0.169 | acc = 0.936
# --- Epoch 31/100:
# Train      -> loss = 0.121 | acc = 0.957
# Validation -> loss = 0.165 | acc = 0.938
# --- Epoch 32/100:
# Train      -> loss = 0.117 | acc = 0.958
# Validation -> loss = 0.164 | acc = 0.942
# --- Epoch 33/100:
# Train      -> loss = 0.115 | acc = 0.959
# Validation -> loss = 0.160 | acc = 0.942
# --- Epoch 34/100:
# Train      -> loss = 0.113 | acc = 0.960
# Validation -> loss = 0.165 | acc = 0.943
# --- Epoch 35/100:
# Train      -> loss = 0.112 | acc = 0.960
# Validation -> loss = 0.168 | acc = 0.944
# --- Epoch 36/100:
# Train      -> loss = 0.109 | acc = 0.961
# Validation -> loss = 0.162 | acc = 0.945
# --- Epoch 37/100:
# Train      -> loss = 0.109 | acc = 0.960
# Validation -> loss = 0.167 | acc = 0.937
# --- Epoch 38/100:
# Train      -> loss = 0.107 | acc = 0.962
# Validation -> loss = 0.166 | acc = 0.939
# --- Epoch 39/100:
# Train      -> loss = 0.105 | acc = 0.963
# Validation -> loss = 0.159 | acc = 0.945
# --- Epoch 40/100:
# Train      -> loss = 0.106 | acc = 0.963
# Validation -> loss = 0.172 | acc = 0.936
# --- Epoch 41/100:
# Train      -> loss = 0.104 | acc = 0.963
# Validation -> loss = 0.188 | acc = 0.928
# --- Epoch 42/100:
# Train      -> loss = 0.102 | acc = 0.963
# Validation -> loss = 0.162 | acc = 0.943
# --- Epoch 43/100:
# Train      -> loss = 0.101 | acc = 0.965
# Validation -> loss = 0.164 | acc = 0.945
# --- Epoch 44/100:
# Train      -> loss = 0.099 | acc = 0.967
# Validation -> loss = 0.162 | acc = 0.944
# --- Epoch 45/100:
# Train      -> loss = 0.100 | acc = 0.966
# Validation -> loss = 0.167 | acc = 0.945
# --- Epoch 46/100:
# Train      -> loss = 0.097 | acc = 0.967
# Validation -> loss = 0.169 | acc = 0.937
# --- Epoch 47/100:
# Train      -> loss = 0.096 | acc = 0.966
# Validation -> loss = 0.163 | acc = 0.945
# --- Epoch 48/100:
# Train      -> loss = 0.093 | acc = 0.968
# Validation -> loss = 0.168 | acc = 0.940
# --- Epoch 49/100:
# Train      -> loss = 0.093 | acc = 0.969
# Validation -> loss = 0.169 | acc = 0.943
# --- Epoch 50/100:
# Train      -> loss = 0.092 | acc = 0.968
# Validation -> loss = 0.163 | acc = 0.945
# --- Epoch 51/100:
# Train      -> loss = 0.090 | acc = 0.969
# Validation -> loss = 0.164 | acc = 0.945
# --- Epoch 52/100:
# Train      -> loss = 0.090 | acc = 0.969
# Validation -> loss = 0.176 | acc = 0.937
# --- Epoch 53/100:
# Train      -> loss = 0.087 | acc = 0.971
# Validation -> loss = 0.164 | acc = 0.944
# --- Epoch 54/100:
# Train      -> loss = 0.088 | acc = 0.970
# Validation -> loss = 0.172 | acc = 0.937
# --- Epoch 55/100:
# Train      -> loss = 0.084 | acc = 0.971
# Validation -> loss = 0.172 | acc = 0.944
# --- Epoch 56/100:
# Train      -> loss = 0.084 | acc = 0.972
# Validation -> loss = 0.169 | acc = 0.944
# --- Epoch 57/100:
# Train      -> loss = 0.082 | acc = 0.973
# Validation -> loss = 0.176 | acc = 0.933
# --- Epoch 58/100:
# Train      -> loss = 0.081 | acc = 0.973
# Validation -> loss = 0.166 | acc = 0.943
# --- Epoch 59/100:
# Train      -> loss = 0.081 | acc = 0.973
# Validation -> loss = 0.176 | acc = 0.937
# --- Epoch 60/100:
# Train      -> loss = 0.079 | acc = 0.973
# Validation -> loss = 0.172 | acc = 0.944
# --- Epoch 61/100:
# Train      -> loss = 0.078 | acc = 0.973
# Validation -> loss = 0.173 | acc = 0.945
# --- Epoch 62/100:
# Train      -> loss = 0.076 | acc = 0.974
# Validation -> loss = 0.177 | acc = 0.937
# --- Epoch 63/100:
# Train      -> loss = 0.077 | acc = 0.972
# Validation -> loss = 0.174 | acc = 0.943
# --- Epoch 64/100:
# Train      -> loss = 0.076 | acc = 0.974
# Validation -> loss = 0.168 | acc = 0.940
# --- Epoch 65/100:
# Train      -> loss = 0.074 | acc = 0.975
# Validation -> loss = 0.169 | acc = 0.941
# --- Epoch 66/100:
# Train      -> loss = 0.073 | acc = 0.975
# Validation -> loss = 0.193 | acc = 0.930
# --- Epoch 67/100:
# Train      -> loss = 0.073 | acc = 0.975
# Validation -> loss = 0.181 | acc = 0.935
# --- Epoch 68/100:
# Train      -> loss = 0.071 | acc = 0.975
# Validation -> loss = 0.176 | acc = 0.940
# --- Epoch 69/100:
# Train      -> loss = 0.069 | acc = 0.976
# Validation -> loss = 0.182 | acc = 0.944
# --- Epoch 70/100:
# Train      -> loss = 0.069 | acc = 0.977
# Validation -> loss = 0.175 | acc = 0.944
# --- Epoch 71/100:
# Train      -> loss = 0.067 | acc = 0.978
# Validation -> loss = 0.179 | acc = 0.937
# --- Epoch 72/100:
# Train      -> loss = 0.066 | acc = 0.977
# Validation -> loss = 0.182 | acc = 0.934
# --- Epoch 73/100:
# Train      -> loss = 0.065 | acc = 0.979
# Validation -> loss = 0.182 | acc = 0.938
# --- Epoch 74/100:
# Train      -> loss = 0.064 | acc = 0.979
# Validation -> loss = 0.181 | acc = 0.939
# --- Epoch 75/100:
# Train      -> loss = 0.063 | acc = 0.979
# Validation -> loss = 0.188 | acc = 0.945
# --- Epoch 76/100:
# Train      -> loss = 0.062 | acc = 0.980
# Validation -> loss = 0.181 | acc = 0.944
# --- Epoch 77/100:
# Train      -> loss = 0.062 | acc = 0.980
# Validation -> loss = 0.181 | acc = 0.942
# --- Epoch 78/100:
# Train      -> loss = 0.061 | acc = 0.980
# Validation -> loss = 0.179 | acc = 0.942
# --- Epoch 79/100:
# Train      -> loss = 0.060 | acc = 0.982
# Validation -> loss = 0.181 | acc = 0.939
# --- Epoch 80/100:
# Train      -> loss = 0.058 | acc = 0.982
# Validation -> loss = 0.183 | acc = 0.939
# --- Epoch 81/100:
# Train      -> loss = 0.058 | acc = 0.981
# Validation -> loss = 0.197 | acc = 0.942
# --- Epoch 82/100:
# Train      -> loss = 0.056 | acc = 0.982
# Validation -> loss = 0.185 | acc = 0.939
# --- Epoch 83/100:
# Train      -> loss = 0.055 | acc = 0.982
# Validation -> loss = 0.187 | acc = 0.940
# --- Epoch 84/100:
# Train      -> loss = 0.055 | acc = 0.983
# Validation -> loss = 0.184 | acc = 0.939
# --- Epoch 85/100:
# Train      -> loss = 0.054 | acc = 0.983
# Validation -> loss = 0.188 | acc = 0.939
# --- Epoch 86/100:
# Train      -> loss = 0.053 | acc = 0.984
# Validation -> loss = 0.198 | acc = 0.940
# --- Epoch 87/100:
# Train      -> loss = 0.051 | acc = 0.984
# Validation -> loss = 0.197 | acc = 0.938
# --- Epoch 88/100:
# Train      -> loss = 0.051 | acc = 0.984
# Validation -> loss = 0.193 | acc = 0.935
# --- Epoch 89/100:
# Train      -> loss = 0.051 | acc = 0.984
# Validation -> loss = 0.195 | acc = 0.938
# --- Epoch 90/100:
# Train      -> loss = 0.050 | acc = 0.985
# Validation -> loss = 0.194 | acc = 0.941
# --- Epoch 91/100:
# Train      -> loss = 0.049 | acc = 0.984
# Validation -> loss = 0.192 | acc = 0.940
# --- Epoch 92/100:
# Train      -> loss = 0.048 | acc = 0.985
# Validation -> loss = 0.202 | acc = 0.935
# --- Epoch 93/100:
# Train      -> loss = 0.046 | acc = 0.986
# Validation -> loss = 0.193 | acc = 0.941
# --- Epoch 94/100:
# Train      -> loss = 0.047 | acc = 0.985
# Validation -> loss = 0.195 | acc = 0.937
# --- Epoch 95/100:
# Train      -> loss = 0.045 | acc = 0.986
# Validation -> loss = 0.195 | acc = 0.941
# --- Epoch 96/100:
# Train      -> loss = 0.044 | acc = 0.986
# Validation -> loss = 0.200 | acc = 0.935
# --- Epoch 97/100:
# Train      -> loss = 0.044 | acc = 0.987
# Validation -> loss = 0.208 | acc = 0.931
# --- Epoch 98/100:
# Train      -> loss = 0.043 | acc = 0.987
# Validation -> loss = 0.198 | acc = 0.938
# --- Epoch 99/100:
# Train      -> loss = 0.042 | acc = 0.987
# Validation -> loss = 0.201 | acc = 0.941
# --- Epoch 100/100:
# Train      -> loss = 0.042 | acc = 0.987
# Validation -> loss = 0.205 | acc = 0.937

# %%
# rectangular kernels?
set_seed(SEED)
k1_size = (3, 5)
k2_size = (3, 5)
model = Conv2Net(k1_size, k2_size)
train_loss, val_loss, train_acc, val_acc, model = train_model(
    model, train_dataset, val_dataset, batch_size, num_epochs, lr
)
fig = plot_train_val_loss(
    num_epochs,
    train_loss,
    train_acc,
    val_loss,
    val_acc,
    title=f"lr={lr} | bs={batch_size}",
)
# Out:
# --- Epoch 1/40:
# Train      -> loss = 0.660 | acc = 0.735
# Validation -> loss = 0.356 | acc = 0.874
# --- Epoch 2/40:
# Train      -> loss = 0.302 | acc = 0.889
# Validation -> loss = 0.269 | acc = 0.904
# --- Epoch 3/40:
# Train      -> loss = 0.244 | acc = 0.908
# Validation -> loss = 0.242 | acc = 0.909
# --- Epoch 4/40:
# Train      -> loss = 0.218 | acc = 0.918
# Validation -> loss = 0.222 | acc = 0.918
# --- Epoch 5/40:
# Train      -> loss = 0.205 | acc = 0.922
# Validation -> loss = 0.212 | acc = 0.921
# --- Epoch 6/40:
# Train      -> loss = 0.193 | acc = 0.927
# Validation -> loss = 0.205 | acc = 0.923
# --- Epoch 7/40:
# Train      -> loss = 0.186 | acc = 0.931
# Validation -> loss = 0.200 | acc = 0.924
# --- Epoch 8/40:
# Train      -> loss = 0.181 | acc = 0.930
# Validation -> loss = 0.207 | acc = 0.931
# --- Epoch 9/40:
# Train      -> loss = 0.176 | acc = 0.934
# Validation -> loss = 0.196 | acc = 0.929
# --- Epoch 10/40:
# Train      -> loss = 0.169 | acc = 0.937
# Validation -> loss = 0.196 | acc = 0.930
# --- Epoch 11/40:
# Train      -> loss = 0.167 | acc = 0.938
# Validation -> loss = 0.188 | acc = 0.930
# --- Epoch 12/40:
# Train      -> loss = 0.162 | acc = 0.941
# Validation -> loss = 0.186 | acc = 0.930
# --- Epoch 13/40:
# Train      -> loss = 0.159 | acc = 0.941
# Validation -> loss = 0.190 | acc = 0.933
# --- Epoch 14/40:
# Train      -> loss = 0.154 | acc = 0.944
# Validation -> loss = 0.186 | acc = 0.931
# --- Epoch 15/40:
# Train      -> loss = 0.153 | acc = 0.942
# Validation -> loss = 0.180 | acc = 0.936
# --- Epoch 16/40:
# Train      -> loss = 0.149 | acc = 0.945
# Validation -> loss = 0.183 | acc = 0.935
# --- Epoch 17/40:
# Train      -> loss = 0.147 | acc = 0.946
# Validation -> loss = 0.188 | acc = 0.935
# --- Epoch 18/40:
# Train      -> loss = 0.144 | acc = 0.946
# Validation -> loss = 0.180 | acc = 0.936
# --- Epoch 19/40:
# Train      -> loss = 0.140 | acc = 0.949
# Validation -> loss = 0.199 | acc = 0.930
# --- Epoch 20/40:
# Train      -> loss = 0.139 | acc = 0.949
# Validation -> loss = 0.182 | acc = 0.934
# --- Epoch 21/40:
# Train      -> loss = 0.135 | acc = 0.950
# Validation -> loss = 0.178 | acc = 0.937
# --- Epoch 22/40:
# Train      -> loss = 0.132 | acc = 0.951
# Validation -> loss = 0.192 | acc = 0.935
# --- Epoch 23/40:
# Train      -> loss = 0.131 | acc = 0.951
# Validation -> loss = 0.182 | acc = 0.929
# --- Epoch 24/40:
# Train      -> loss = 0.127 | acc = 0.952
# Validation -> loss = 0.180 | acc = 0.935
# --- Epoch 25/40:
# Train      -> loss = 0.124 | acc = 0.955
# Validation -> loss = 0.178 | acc = 0.932
# --- Epoch 26/40:
# Train      -> loss = 0.122 | acc = 0.956
# Validation -> loss = 0.196 | acc = 0.933
# --- Epoch 27/40:
# Train      -> loss = 0.120 | acc = 0.956
# Validation -> loss = 0.206 | acc = 0.933
# --- Epoch 28/40:
# Train      -> loss = 0.118 | acc = 0.957
# Validation -> loss = 0.181 | acc = 0.929
# --- Epoch 29/40:
# Train      -> loss = 0.115 | acc = 0.958
# Validation -> loss = 0.185 | acc = 0.939
# --- Epoch 30/40:
# Train      -> loss = 0.113 | acc = 0.959
# Validation -> loss = 0.201 | acc = 0.931
# --- Epoch 31/40:
# Train      -> loss = 0.111 | acc = 0.960
# Validation -> loss = 0.184 | acc = 0.935
# --- Epoch 32/40:
# Train      -> loss = 0.109 | acc = 0.960
# Validation -> loss = 0.185 | acc = 0.930
# --- Epoch 33/40:
# Train      -> loss = 0.106 | acc = 0.961
# Validation -> loss = 0.193 | acc = 0.934
# --- Epoch 34/40:
# Train      -> loss = 0.104 | acc = 0.962
# Validation -> loss = 0.188 | acc = 0.937
# --- Epoch 35/40:
# Train      -> loss = 0.100 | acc = 0.963
# Validation -> loss = 0.182 | acc = 0.936
# --- Epoch 36/40:
# Train      -> loss = 0.098 | acc = 0.964
# Validation -> loss = 0.190 | acc = 0.937
# --- Epoch 37/40:
# Train      -> loss = 0.098 | acc = 0.965
# Validation -> loss = 0.200 | acc = 0.932
# --- Epoch 38/40:
# Train      -> loss = 0.094 | acc = 0.966
# Validation -> loss = 0.192 | acc = 0.936
# --- Epoch 39/40:
# Train      -> loss = 0.092 | acc = 0.966
# Validation -> loss = 0.195 | acc = 0.937
# --- Epoch 40/40:
# Train      -> loss = 0.089 | acc = 0.968
# Validation -> loss = 0.193 | acc = 0.936

# %%
# Test Data Augmentation on X_train

def augment_data_with_noise(X_train, y_train, noise_power, aug_factor=0.5):
    np.random.seed(SEED)
    map_size = (11, 61)
    n_train = X_train.shape[0]
    n_augmented = int(aug_factor * n_train)
    samples_idx = np.random.choice(n_train, n_augmented, replace=False)
    X_aug = np.zeros((n_train + n_augmented, *map_size))
    y_aug = np.zeros(n_train + n_augmented)
    X_aug[:n_train, :, :] = X_train
    y_aug[:n_train] = y_train
    for i, sid in enumerate(samples_idx):
        X_aug[n_train + i, :, :] = X_train[sid, :, :] + np.sqrt(
            noise_power
        ) * np.random.randn(*map_size)
        y_aug[n_train + i] = y_train[sid]
    return X_aug, y_aug

# %%
set_seed(SEED)
X_aug, y_aug = augment_data_with_noise(X_train, y_train, noise_power=1, aug_factor=0.5)
train_dataset = MapsDataset(X_aug, y_aug)
k1_size = (3, 3)
k2_size = (3, 3)
model = Conv2Net(k1_size, k2_size)
train_loss, val_loss, train_acc, val_acc, model = train_model(
    model, train_dataset, val_dataset, batch_size, num_epochs, lr
)
fig = plot_train_val_loss(
    num_epochs,
    train_loss,
    train_acc,
    val_loss,
    val_acc,
    title=f"lr={lr} | bs={batch_size}",
)
# Out:
# --- Epoch 1/40:
# Train      -> loss = 0.673 | acc = 0.715
# Validation -> loss = 0.375 | acc = 0.858
# --- Epoch 2/40:
# Train      -> loss = 0.316 | acc = 0.885
# Validation -> loss = 0.268 | acc = 0.911
# --- Epoch 3/40:
# Train      -> loss = 0.259 | acc = 0.905
# Validation -> loss = 0.246 | acc = 0.917
# --- Epoch 4/40:
# Train      -> loss = 0.239 | acc = 0.909
# Validation -> loss = 0.230 | acc = 0.921
# --- Epoch 5/40:
# Train      -> loss = 0.227 | acc = 0.915
# Validation -> loss = 0.220 | acc = 0.922
# --- Epoch 6/40:
# Train      -> loss = 0.217 | acc = 0.918
# Validation -> loss = 0.211 | acc = 0.923
# --- Epoch 7/40:
# Train      -> loss = 0.209 | acc = 0.920
# Validation -> loss = 0.211 | acc = 0.924
# --- Epoch 8/40:
# Train      -> loss = 0.203 | acc = 0.922
# Validation -> loss = 0.199 | acc = 0.930
# --- Epoch 9/40:
# Train      -> loss = 0.197 | acc = 0.926
# Validation -> loss = 0.193 | acc = 0.932
# --- Epoch 10/40:
# Train      -> loss = 0.191 | acc = 0.928
# Validation -> loss = 0.193 | acc = 0.931
# --- Epoch 11/40:
# Train      -> loss = 0.185 | acc = 0.930
# Validation -> loss = 0.188 | acc = 0.931
# --- Epoch 12/40:
# Train      -> loss = 0.181 | acc = 0.930
# Validation -> loss = 0.186 | acc = 0.932
# --- Epoch 13/40:
# Train      -> loss = 0.177 | acc = 0.932
# Validation -> loss = 0.183 | acc = 0.932
# --- Epoch 14/40:
# Train      -> loss = 0.174 | acc = 0.933
# Validation -> loss = 0.189 | acc = 0.932
# --- Epoch 15/40:
# Train      -> loss = 0.169 | acc = 0.935
# Validation -> loss = 0.189 | acc = 0.931
# --- Epoch 16/40:
# Train      -> loss = 0.167 | acc = 0.936
# Validation -> loss = 0.180 | acc = 0.932
# --- Epoch 17/40:
# Train      -> loss = 0.164 | acc = 0.936
# Validation -> loss = 0.180 | acc = 0.932
# --- Epoch 18/40:
# Train      -> loss = 0.158 | acc = 0.940
# Validation -> loss = 0.181 | acc = 0.936
# --- Epoch 19/40:
# Train      -> loss = 0.155 | acc = 0.941
# Validation -> loss = 0.176 | acc = 0.937
# --- Epoch 20/40:
# Train      -> loss = 0.154 | acc = 0.941
# Validation -> loss = 0.174 | acc = 0.936
# --- Epoch 21/40:
# Train      -> loss = 0.150 | acc = 0.944
# Validation -> loss = 0.188 | acc = 0.932
# --- Epoch 22/40:
# Train      -> loss = 0.148 | acc = 0.943
# Validation -> loss = 0.178 | acc = 0.936
# --- Epoch 23/40:
# Train      -> loss = 0.144 | acc = 0.945
# Validation -> loss = 0.183 | acc = 0.934
# --- Epoch 24/40:
# Train      -> loss = 0.140 | acc = 0.947
# Validation -> loss = 0.181 | acc = 0.930
# --- Epoch 25/40:
# Train      -> loss = 0.138 | acc = 0.947
# Validation -> loss = 0.183 | acc = 0.932
# --- Epoch 26/40:
# Train      -> loss = 0.137 | acc = 0.948
# Validation -> loss = 0.169 | acc = 0.938
# --- Epoch 27/40:
# Train      -> loss = 0.134 | acc = 0.949
# Validation -> loss = 0.172 | acc = 0.938
# --- Epoch 28/40:
# Train      -> loss = 0.132 | acc = 0.949
# Validation -> loss = 0.180 | acc = 0.935
# --- Epoch 29/40:
# Train      -> loss = 0.129 | acc = 0.951
# Validation -> loss = 0.173 | acc = 0.937
# --- Epoch 30/40:
# Train      -> loss = 0.127 | acc = 0.951
# Validation -> loss = 0.167 | acc = 0.940
# --- Epoch 31/40:
# Train      -> loss = 0.123 | acc = 0.953
# Validation -> loss = 0.173 | acc = 0.941
# --- Epoch 32/40:
# Train      -> loss = 0.120 | acc = 0.955
# Validation -> loss = 0.182 | acc = 0.932
# --- Epoch 33/40:
# Train      -> loss = 0.119 | acc = 0.955
# Validation -> loss = 0.179 | acc = 0.936
# --- Epoch 34/40:
# Train      -> loss = 0.117 | acc = 0.955
# Validation -> loss = 0.176 | acc = 0.936
# --- Epoch 35/40:
# Train      -> loss = 0.113 | acc = 0.956
# Validation -> loss = 0.171 | acc = 0.939
# --- Epoch 36/40:
# Train      -> loss = 0.112 | acc = 0.957
# Validation -> loss = 0.173 | acc = 0.939
# --- Epoch 37/40:
# Train      -> loss = 0.109 | acc = 0.959
# Validation -> loss = 0.186 | acc = 0.933
# --- Epoch 38/40:
# Train      -> loss = 0.108 | acc = 0.959
# Validation -> loss = 0.176 | acc = 0.940
# --- Epoch 39/40:
# Train      -> loss = 0.104 | acc = 0.961
# Validation -> loss = 0.174 | acc = 0.939
# --- Epoch 40/40:
# Train      -> loss = 0.103 | acc = 0.962
# Validation -> loss = 0.181 | acc = 0.936
